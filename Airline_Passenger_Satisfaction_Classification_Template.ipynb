# %% [markdown]
# <a href="https://colab.research.google.com/github/Mogatala8374/Airline-Passenger-Satisfaction/blob/main/Airline_Passenger_Satisfaction_Classification_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -   Airline Passenger Satisfaction

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  MOGATALA YUVARAJU
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# **Project Summary (500–600 Words)**
#
# This project focuses on building a Machine Learning Classification model to predict passenger satisfaction in the airline industry using the Airline Passenger Satisfaction dataset. The primary objective is to identify whether a passenger is Satisfied or Neutral/Dissatisfied based on various demographic, travel, and service-related attributes. Predicting customer satisfaction enables airlines to understand passenger expectations, improve service quality, increase customer retention, and make data-driven business decisions. This summary is suitable for the Project Summary section of the provided capstone template.
#
# The project begins with data understanding and exploration, where the dataset is loaded using the Pandas library. Initial analysis includes examining the dataset structure, checking data types, identifying duplicate records, and detecting missing values. Descriptive statistics are generated to understand the distribution of numerical variables such as age, flight distance, departure delay, and arrival delay. Appropriate preprocessing techniques are applied to ensure the dataset is clean and ready for model development.
#
# Extensive Exploratory Data Analysis (EDA) is performed using Matplotlib and Seaborn to identify meaningful patterns and relationships within the data. More than fifteen visualizations are created, including count plots, histograms, box plots, correlation heatmaps, pair plots, and bar charts. These visualizations help analyze customer satisfaction across different categories such as gender, customer type, travel class, type of travel, seat comfort, online boarding, inflight entertainment, baggage handling, and cleanliness. Each visualization is accompanied by business insights explaining how the observed trends can help airlines improve customer experience and operational efficiency.
#
# After EDA, the project proceeds with feature engineering and data preprocessing. Missing values are handled using suitable imputation techniques, duplicate records are removed, and categorical variables are encoded using Label Encoding. Numerical features are standardized using StandardScaler to improve the performance of distance-based algorithms. The dataset is then divided into training and testing sets using an appropriate train-test split to evaluate model performance on unseen data.
#
# Several supervised classification algorithms from the Scikit-learn library are implemented and compared. These include Logistic Regression, Decision Tree Classifier, Random Forest Classifier, K-Nearest Neighbors (KNN), Support Vector Machine (SVM), and Gaussian Naive Bayes. Each model is trained on the processed training dataset and evaluated using multiple performance metrics, including Accuracy, Precision, Recall, F1-Score, Confusion Matrix, and Classification Report. Cross-validation is performed to assess model stability, while GridSearchCV is used for hyperparameter tuning to improve predictive performance and reduce overfitting.
#
# The performance of all classification models is compared systematically to identify the most suitable model for predicting passenger satisfaction. Feature importance analysis is also conducted to determine the factors that most strongly influence customer satisfaction. Variables such as online boarding, seat comfort, inflight entertainment, cleanliness, onboard service, and class are expected to have significant contributions toward prediction accuracy.
#
# Overall, this project demonstrates a complete end-to-end machine learning workflow, including data preprocessing, visualization, feature engineering, model training, evaluation, optimization, and interpretation. The insights obtained from this analysis can help airline companies prioritize improvements in customer service, enhance passenger satisfaction, reduce customer dissatisfaction, and strengthen customer loyalty. The final optimized classification model provides a reliable decision-support tool for predicting passenger satisfaction and enables airlines to make informed strategic decisions based on data-driven insights.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/Mogatala8374/Airline-Passenger-Satisfaction/blob/main/Airline_Passenger_Satisfaction_Classification_Template.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# The airline industry operates in a highly competitive environment where customer satisfaction plays a crucial role in maintaining customer loyalty and achieving long-term business success. Passengers evaluate their travel experience based on several factors, including seat comfort, online boarding, inflight entertainment, cleanliness, baggage handling, onboard service, flight punctuality, and overall service quality. Identifying the factors that influence passenger satisfaction is essential for airlines to improve their services and enhance the customer experience.
#
# The objective of this project is to develop a Machine Learning Classification model that predicts whether a passenger is Satisfied or Neutral/Dissatisfied using the Airline Passenger Satisfaction dataset. The dataset contains demographic information, travel details, and service quality ratings that can be used to understand passenger behavior and satisfaction levels.
#
# The project involves performing data preprocessing, handling missing values, exploratory data analysis, feature engineering, and building multiple classification models using Scikit-learn. Models such as Logistic Regression, Decision Tree, Random Forest, K-Nearest Neighbors (KNN), Support Vector Machine (SVM), and Gaussian Naive Bayes will be trained and evaluated using performance metrics including Accuracy, Precision, Recall, F1-Score, Confusion Matrix, and Cross-Validation. Hyperparameter tuning will also be applied to improve model performance.
#
# The final objective is to identify the best-performing classification model and determine the most influential factors affecting passenger satisfaction. The insights generated from this project will help airline companies make data-driven decisions to improve service quality, enhance customer satisfaction, increase customer retention, and strengthen their competitive position in the aviation industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

df.shape
# Out:
# (103904, 25)

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 103904
# Columns : 25

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

print("Duplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing = df.isnull().sum()

missing = missing[missing>0]

missing.sort_values(ascending=False)
# Out:
# Arrival Delay in Minutes    310
# dtype: int64

# %%
# Visualizing the missing values

plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),
            cbar=False,
            cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Why this chart?**
#
# Heatmap quickly identifies missing values in every feature.
#
# **Insight**
#
# Columns with missing values require preprocessing.
#
# **Business Impact**
#
# Handling missing values improves model performance.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Dataset Describe

df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | **Variable Name**                     | **Data Type**            | **Description**                                                                                                            |
# | ------------------------------------- | ------------------------ | -------------------------------------------------------------------------------------------------------------------------- |
# | **Unnamed: 0 / id**                   | Integer                  | Unique identifier for each passenger record. Not useful for prediction and can be removed.                                 |
# | **Gender**                            | Object (Categorical)     | Gender of the passenger (Male/Female).                                                                                     |
# | **Customer Type**                     | Object (Categorical)     | Indicates whether the passenger is a Loyal Customer or a Disloyal Customer.                                                |
# | **Age**                               | Integer                  | Age of the passenger in years.                                                                                             |
# | **Type of Travel**                    | Object (Categorical)     | Purpose of travel (Business Travel or Personal Travel).                                                                    |
# | **Class**                             | Object (Categorical)     | Travel class chosen by the passenger (Business, Eco, Eco Plus).                                                            |
# | **Flight Distance**                   | Integer                  | Distance traveled by the passenger in kilometers (or miles depending on dataset).                                          |
# | **Inflight wifi service**             | Integer (Ordinal)        | Passenger rating for inflight Wi-Fi service (0–5).                                                                         |
# | **Departure/Arrival time convenient** | Integer (Ordinal)        | Rating for convenience of departure and arrival timings (0–5).                                                             |
# | **Ease of Online booking**            | Integer (Ordinal)        | Rating for ease of online booking (0–5).                                                                                   |
# | **Gate location**                     | Integer (Ordinal)        | Rating for gate location convenience (0–5).                                                                                |
# | **Food and drink**                    | Integer (Ordinal)        | Rating for food and beverage quality (0–5).                                                                                |
# | **Online boarding**                   | Integer (Ordinal)        | Rating for online boarding experience (0–5).                                                                               |
# | **Seat comfort**                      | Integer (Ordinal)        | Rating for seat comfort during the flight (0–5).                                                                           |
# | **Inflight entertainment**            | Integer (Ordinal)        | Rating for inflight entertainment facilities (0–5).                                                                        |
# | **On-board service**                  | Integer (Ordinal)        | Rating for onboard staff services (0–5).                                                                                   |
# | **Leg room service**                  | Integer (Ordinal)        | Rating for legroom availability and comfort (0–5).                                                                         |
# | **Baggage handling**                  | Integer (Ordinal)        | Rating for baggage handling services (0–5).                                                                                |
# | **Check-in service**                  | Integer (Ordinal)        | Rating for airport check-in service (0–5).                                                                                 |
# | **Inflight service**                  | Integer (Ordinal)        | Rating for overall inflight service (0–5).                                                                                 |
# | **Cleanliness**                       | Integer (Ordinal)        | Rating for aircraft cleanliness (0–5).                                                                                     |
# | **Departure Delay in Minutes**        | Integer                  | Delay experienced before departure (in minutes).                                                                           |
# | **Arrival Delay in Minutes**          | Float                    | Delay experienced upon arrival (in minutes). May contain missing values.                                                   |
# | **Satisfaction**                      | Object (Target Variable) | Passenger satisfaction status (**Satisfied** or **Neutral/Dissatisfied**). This is the target variable for classification. |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

unique_values=pd.DataFrame(df.nunique(),
                           columns=["Unique Values"])
unique_values.sort_values("Unique Values",
                          ascending=False)
# Out:
#                                    Unique Values
# Unnamed: 0                                103904
# id                                        103904
# Flight Distance                             3802
# Arrival Delay in Minutes                     455
# Departure Delay in Minutes                   446
# Age                                           75
# Departure/Arrival time convenient              6
# Ease of Online booking                         6
# Inflight wifi service                          6
# On-board service                               6
# Inflight entertainment                         6
# Leg room service                               6
# Checkin service                                6
# Online boarding                                6
# Seat comfort                                   6
# Gate location                                  6
# Food and drink                                 6
# Cleanliness                                    6
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %% [markdown]
# **Unique Values**

# %%
for col in df.columns:
    print(col)
    print(df[col].nunique())
    print("-"*50)
# Out:
# Unnamed: 0
# 103904
# --------------------------------------------------
# id
# 103904
# --------------------------------------------------
# Gender
# 2
# --------------------------------------------------
# Customer Type
# 2
# --------------------------------------------------
# Age
# 75
# --------------------------------------------------
# Type of Travel
# 2
# --------------------------------------------------
# Class
# 3
# --------------------------------------------------
# Flight Distance
# 3802
# --------------------------------------------------
# Inflight wifi service
# 6
# --------------------------------------------------
# Departure/Arrival time convenient
# 6
# --------------------------------------------------
# Ease of Online booking
# 6
# --------------------------------------------------
# Gate location
# 6
# --------------------------------------------------
# Food and drink
# 6
# --------------------------------------------------
# Online boarding
# 6
# ...

# %% [markdown]
# **Drop Unnecessary Columns**

# %%
columns_to_drop = [col for col in ["Unnamed: 0", "id"] if col in df.columns]
if columns_to_drop:
    df.drop(columns_to_drop,
            axis=1,
            inplace=True)
else:
    print("Columns 'Unnamed: 0' and 'id' not found in DataFrame.")

# %% [markdown]
# **Check Missing Values Again**

# %%
df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %% [markdown]
# **Fill Missing Values**

# %%
for col in df.columns:

    if df[col].dtype=="object":
        df[col].fillna(df[col].mode()[0],
                       inplace=True)

    else:
        df[col].fillna(df[col].median(),
                       inplace=True)

# %% [markdown]
# **Verify Missing Values**

# %%
df.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# **Target Variable**

# %%
df["satisfaction"].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. **Dropped Unnecessary Columns**: The columns 'Unnamed: 0' and 'id' were identified as unique identifiers not useful for prediction and were subsequently dropped from the DataFrame.
# 2. **Handled Missing Values**: The dataset had 310 missing values in the 'Arrival Delay in Minutes' column. These missing numerical values were imputed using the median of the column. This approach was chosen to maintain data integrity and ensure all rows could be used for analysis without introducing bias from extreme values.
# 3. **Target Variable Distribution**: An analysis of the 'satisfaction' column revealed that there are more 'neutral or dissatisfied' passengers (58,879) than 'satisfied' passengers (45,025). This indicates a slight imbalance in the target variable, which might need to be considered during model training.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 (Target Distribution)

# %%
# Chart - 1 visualization code
plt.figure(figsize=(6,5))
sns.countplot(data=df,
              x="satisfaction",
              palette="Set2")
plt.title("Passenger Satisfaction")
plt.xlabel("Satisfaction")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is ideal for visualizing the frequency distribution of the target variable in a classification problem.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the number of satisfied passengers compared with neutral or dissatisfied passengers. It also helps determine whether the dataset is balanced or imbalanced.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. If dissatisfied passengers form a large proportion, the airline should identify the causes and improve its services. High dissatisfaction directly affects customer retention, brand reputation, and future revenue.

# %% [markdown]
# #### Chart - 2 (Gender Distribution)

# %%
# Chart - 2 visualization code

plt.figure(figsize=(6,5))
sns.countplot(data=df,
              x="Gender",
              palette="pastel")
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot effectively compares the number of male and female passengers in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset contains a nearly balanced distribution of male and female passengers, indicating that customer feedback is collected from both genders.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. A balanced customer base allows the airline to develop services that satisfy both male and female passengers. If one gender consistently reports lower satisfaction, targeted improvements can be implemented.

# %% [markdown]
# #### Chart - 3 (Customer Type)

# %%
# Chart - 3 visualizatio

plt.figure(figsize=(7,7))
df['Customer Type'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['gold','lightgreen'],
    explode=[0.03,0]
)
plt.title("Customer Type Distribution")
plt.ylabel("")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart clearly compares loyal customers with disloyal customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows whether loyal customers constitute the majority of passengers. Loyal customers generally contribute more to long-term airline revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Retaining loyal customers increases repeat bookings and reduces marketing costs. A decline in loyal customers may indicate poor customer experience and could negatively impact future profits.

# %% [markdown]
# #### Chart - 4 (Travel Type)

# %%
# Chart - 4 visualization code

plt.figure(figsize=(6,5))
sns.countplot(data=df,
              x="Type of Travel",
              palette="Set1")
plt.xticks(rotation=20)
plt.title("Travel Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart compares Business Travel and Personal Travel, helping identify the dominant travel purpose.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Business travelers often represent a significant portion of passengers and usually have higher expectations regarding airline services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Improving services for business travelers can increase customer loyalty and premium ticket sales. Dissatisfaction among business travelers may lead to substantial revenue loss because they travel more frequently.

# %% [markdown]
# #### Chart - 5 (Class Distribution)

# %%
# Chart - 5 visualization code

plt.figure(figsize=(6,5))
sns.countplot(data=df,
              x="Class",
              palette="Paired")
plt.title("Passenger Class")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot effectively compares the number of passengers in Economy, Economy Plus, and Business Class.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The airline serves passengers across multiple travel classes. Business Class passengers usually expect higher-quality services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding class distribution helps allocate resources appropriately. Poor service in Business Class can negatively affect premium revenue and customer loyalty.

# %% [markdown]
# #### Chart - 6 (Age Distribution)

# %%
# Chart - 6 visualization code

plt.figure(figsize=(10,5))
sns.histplot(df["Age"],
             bins=30,
             kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is the most suitable chart for understanding the distribution of continuous numerical variables such as age.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the dominant passenger age groups and shows whether the distribution is skewed or approximately normal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Different age groups have different service expectations. Understanding these demographics enables the airline to provide age-specific services, improving customer satisfaction and loyalty.

# %% [markdown]
# #### Chart - 7 (Flight Distance)

# %%
# Chart - 7 visualization code

plt.figure(figsize=(10,5))
sns.histplot(df["Flight Distance"],
             bins=30,
             kde=True)
plt.title("Flight Distance")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram effectively visualizes how flight distances are distributed among passengers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals whether most passengers travel short, medium, or long distances.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Long-distance passengers generally expect superior in-flight services such as comfortable seating, quality meals, and entertainment. Failure to meet these expectations may reduce customer satisfaction and repeat bookings.

# %% [markdown]
# #### Chart - 8 (Departure Delay)

# %%
# Chart - 8 visualization code

plt.figure(figsize=(10,5))
sns.histplot(df["Departure Delay in Minutes"],
             bins=40,
             kde=True)
plt.title("Departure Delay")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram clearly displays the frequency and severity of departure delays.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most flights experience little or no delay, while a small number have significant delays, indicating the presence of outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Reducing departure delays improves punctuality, customer satisfaction, and airline reputation. Frequent delays increase customer complaints, compensation costs, and loss of trust.

# %% [markdown]
# #### Chart - 9 (Arrival Delay)

# %%
# Chart - 9 visualization code

plt.figure(figsize=(10,5))
sns.histplot(df["Arrival Delay in Minutes"],
             bins=40,
             kde=True)
plt.title("Arrival Delay")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is suitable for analyzing the distribution of arrival delays and identifying extreme values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most flights arrive close to schedule, while a small number experience substantial delays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Timely arrivals enhance passenger satisfaction and strengthen the airline's reputation. Persistent arrival delays can reduce customer confidence, increase operational costs, and negatively affect future ticket sales.

# %% [markdown]
# #### Chart - 10 (Satisfaction vs Gender)

# %%
# Chart - 10 visualization code

plt.figure(figsize=(7,5))
sns.countplot(
    data=df,
    x="Gender",
    hue="satisfaction",
    palette="Set2"
)
plt.title("Passenger Satisfaction by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped count plot is suitable because both Gender and Satisfaction are categorical variables. It helps compare satisfaction levels between male and female passengers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The chart shows the distribution of satisfied and dissatisfied passengers across both genders.
#
# * If the counts are nearly equal, gender has little influence on passenger satisfaction.
#
# * 3. *Any* noticeable difference may indicate varying service perceptions between male and female passengers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ***Positive Business Impact***
#
# Helps airlines determine whether customer experience should be customized for different passenger groups.
# Supports targeted customer satisfaction strategies.
#
# ***Negative Growth***
#
# If one gender consistently reports lower satisfaction, it may indicate service quality issues affecting that customer segment, potentially reducing customer retention.

# %% [markdown]
# #### Chart - 11 (Satisfaction vs Customer Type)

# %%
# Chart - 11 visualization code

plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x="Customer Type",
    hue="satisfaction",
    palette="Dark2"
)
plt.title("Customer Type vs Satisfaction")
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped count plot is suitable because both Gender and Satisfaction are categorical variables. It helps compare satisfaction levels between male and female passengers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Loyal customers generally exhibit higher satisfaction.
# 2.   Disloyal customers tend to report dissatisfaction more frequently.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ***Positive Business Impact***
#
# Helps improve loyalty programs.
# Encourages airlines to retain existing customers.
#
# ***Negative Growth***
#
# A large number of dissatisfied disloyal customers may reduce repeat bookings and increase customer acquisition costs.

# %% [markdown]
# #### Chart - 12  (Satisfaction vs Travel Type)

# %%
# Chart - 12 visualization code
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x="Type of Travel",
    hue="satisfaction",
    palette="viridis"
)
plt.title("Travel Type vs Satisfaction")
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Both variables are categorical, making a grouped count plot the best option for comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Business travelers generally have higher expectations regarding airline services.
# 2. Personal travelers may display different satisfaction patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ***Positive Business Impact***
#
# Helps airlines improve premium services for business travelers.
# Enables personalized service offerings for leisure travelers.
#
# ***Negative Growth***
#
# Unsatisfied business travelers may shift to competitor airlines, causing revenue loss.

# %% [markdown]
# #### Chart - 13 (Cleanliness - PIE CHART)

# %%
# Chart - 13 visualization code

# Calculate average cleanliness rating for each satisfaction category
cleanliness = df.groupby('satisfaction')['Cleanliness'].mean().round(2)
plt.figure(figsize=(7,7))
plt.pie(
    cleanliness,
    labels=cleanliness.index,
    autopct='%1.1f%%',
    startangle=90,
    explode=[0.03, 0],
    colors=['#66b3ff', '#99ff99']
)
plt.title("Average Cleanliness Rating by Satisfaction")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot compares cleanliness ratings between satisfied and dissatisfied passengers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Clean aircraft generally receive higher satisfaction ratings.
#
# 2. Lower cleanliness scores are associated with dissatisfied passengers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact**
#
# Highlights the importance of maintaining high hygiene standards.
# Supports investment in cleaning operations.
#
# **Negative Growth**
#
# Poor cleanliness can reduce customer trust, increase complaints, and negatively affect the airline's brand image.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(18,12))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    linewidths=0.5,
    fmt=".2f"
)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is ideal for identifying relationships among numerical variables and detecting multicollinearity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Reveals positively and negatively correlated features.
#
# 2. Highly correlated variables may contain redundant information.
#
# 3. Helps identify the most influential numerical features.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %%
selected_columns = [
    "Age",
    "Flight Distance",
    "Inflight wifi service",
    "Seat comfort",
    "Cleanliness",
    "Departure Delay in Minutes"
]

sns.pairplot(
    df[selected_columns],
    corner=True
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is useful for visualizing relationships, distributions, and potential outliers among multiple numerical variables simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows pairwise relationships between important numerical features.
#
# Identifies trends, clusters, and possible outliers.
#
# Helps understand feature interactions before model building.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# Handling Missing Values

# %%
# Check Missing Values
df.isnull().sum()

# %% [markdown]
# **Percentage of Missing Values**

# %%
missing_percentage = (df.isnull().sum()/len(df))*100
missing_percentage.sort_values(ascending=False)

# %% [markdown]
# **Fill Missing Values**

# %%
# Numerical Columns

num_cols = df.select_dtypes(include=np.number).columns
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)

# Categorical Columns
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %% [markdown]
# Separate Numerical and Categorical Columns

# %%
# Separate Numerical and Categorical Columns

num_cols = df.select_dtypes(include=['int64','float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

# %% [markdown]
# Fill Numerical Missing Values with Median

# %%
# Fill Numerical Missing Values with Median

for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)

# %% [markdown]
# Fill Categorical Missing Values with Mode

# %%
# Fill Categorical Missing Values with Mode

for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
# Verify Missing Values

df.isnull().sum()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %%
plt.figure(figsize=(8,5))
sns.heatmap(
    df.isnull(),
    cbar=False,
    cmap="viridis"
)
plt.title(
    "Missing Values After Imputation",
    fontsize=18,
    weight="bold"
)
plt.show()

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

numeric_columns = df.select_dtypes(include=np.number).columns
for col in numeric_columns:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# Outlier Treatment using IQR

# %%
for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = np.where(df[col] < lower,
                       lower,
                       df[col])
    df[col] = np.where(df[col] > upper,
                       upper,
                       df[col])

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# *   The Interquartile Range (IQR) method was used to identify outliers.
# *   Extreme values were capped using the lower and upper IQR limits instead of deleting observations.
# *   This approach preserves valuable information while reducing the impact of extreme values on machine learning models.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
cat_cols = df.select_dtypes(include="object").columns
cat_cols

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# *  Label Encoding was applied because machine learning algorithms require numerical inputs.
# *  It efficiently converts categorical values into numeric labels while maintaining a simple representation.
# *  Since the dataset contains binary and low-cardinality categorical variables, Label Encoding is an appropriate choice.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# ==============================
# Feature Manipulation
# ==============================

# Create Total Delay Feature
df['Total Delay'] = (
    df['Departure Delay in Minutes'] +
    df['Arrival Delay in Minutes']
)

# %%
# Create Overall Service Rating
service_features = [
    'Inflight wifi service',
    'Departure/Arrival time convenient',
    'Ease of Online booking',
    'Gate location',
    'Food and drink',
    'Online boarding',
    'Seat comfort',
    'Inflight entertainment',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Inflight service',
    'Cleanliness'
]

# %%
df['Overall Service Rating'] = df[service_features].mean(axis=1)

# %%
# Remove redundant delay columns
df.drop(
    ['Departure Delay in Minutes',
     'Arrival Delay in Minutes'],
    axis=1,
    inplace=True
)

df.head()

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# Define Features and Target

X = df.drop("satisfaction", axis=1)
y = df["satisfaction"]

print("Feature Shape :", X.shape)
print("Target Shape :", y.shape)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# The following feature manipulation techniques were applied:
#
# 1. Created a new feature named Total Delay by combining departure and arrival delays. This provides a better representation of the total travel delay experienced by passengers.
#
# 2.  Created an Overall Service Rating feature by averaging all service-related ratings such as seat comfort, WiFi service, online boarding, cleanliness, baggage handling, and inflight entertainment. This summarizes the passenger's overall service experience.
#
# 3. Removed the individual Departure Delay and Arrival Delay columns after creating the Total Delay feature to reduce redundancy and minimize feature correlation.
#
# **Insights**
#
# 1. Total Delay better reflects the passenger's travel experience than considering departure and arrival delays separately.
#
# 2. Overall Service Rating combines multiple service quality indicators into a single meaningful feature, simplifying the dataset.
#
# 3. These engineered features improve data quality and may enhance the predictive performance of classification models.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# The most important features influencing passenger satisfaction include:
#
# * Overall Service Rating
# * Online Boarding
# * Seat Comfort
# * Inflight WiFi Service
# * Class
# * Type of Travel
# * Customer Type
# * Flight Distance
# * Total Delay
# * Cleanliness
# * Inflight Entertainment
# * On-board Service

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# Dimensionality reduction is not required for this dataset because:
#
# 1. The number of features is relatively small.
# 2. Most features are meaningful and contribute to predicting passenger satisfaction.
# 3. Removing dimensions may reduce interpretability without providing significant performance gains.

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
scaler = StandardScaler()

# Scale the features
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("Training Data :", X_train.shape)
print("Testing Data :", X_test.shape)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# An 80:20 train-test split was used. Eighty percent of the data is used to train the machine learning models, while the remaining twenty percent is reserved for evaluating their performance on unseen data. This ratio provides sufficient training data while ensuring a reliable assessment of model generalization.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1  (Logistic Regression)

# %%
# ML Model - 1 Implementation
# Fit the Algorithm
# Predict on the model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# %% [markdown]
# Model Training

# %%
# Create Model
log_model = LogisticRegression(random_state=42)

# Train Model
log_model.fit(X_train, y_train)

# %% [markdown]
# Prediction

# %%
y_pred_log = log_model.predict(X_test)

# %% [markdown]
# Evaluation Metrics

# %%
accuracy = accuracy_score(y_test, y_pred_log)
precision = precision_score(y_test, y_pred_log)
recall = recall_score(y_test, y_pred_log)
f1 = f1_score(y_test, y_pred_log)

print("Accuracy :", accuracy)
print("Precision :", precision)
print("Recall :", recall)
print("F1 Score :", f1)

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred_log))

# %% [markdown]
# Confusion Matrix

# %%
plt.figure(figsize=(6,5))

ConfusionMatrixDisplay.from_estimator(
    log_model,
    X_test,
    y_test,
    cmap="Blues"
)

plt.title("Logistic Regression Confusion Matrix")

plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart


scores = [accuracy,precision,recall,f1]
labels = ["Accuracy","Precision","Recall","F1 Score"]
plt.figure(figsize=(8,5))
sns.barplot(x=labels,
            y=scores,
            palette="viridis")
plt.ylim(0,1)
plt.title("Logistic Regression Performance")
plt.show()

# %% [markdown]
# Logistic Regression is a supervised classification algorithm used to predict binary outcomes. It estimates the probability of a passenger being Satisfied or Neutral/Dissatisfied.
#
# The evaluation metrics indicate:
#
# **Accuracy** measures overall prediction correctness.
#
# **Precision** measures the proportion of correctly predicted satisfied passengers.
#
# **Recall** measures the ability to identify actual satisfied passengers.
#
# **F1-score** provides a balance between precision and recall.
#
# The evaluation chart shows that Logistic Regression performs well and provides a reliable baseline model.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score

cv_score = cross_val_score(

log_model,

X_scaled,

y,

cv=5,

scoring="accuracy"

)

print(cv_score)

print("Average Accuracy :",cv_score.mean())

# %% [markdown]
# Hyperparameter Tuning (GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {

"C":[0.01,0.1,1,10],

"solver":["liblinear","lbfgs"]

}

grid_log = GridSearchCV(

LogisticRegression(random_state=42),

param_grid,

cv=5,

scoring="accuracy"

)

grid_log.fit(X_train,y_train)

# %% [markdown]
# Best Model

# %%
best_log = grid_log.best_estimator_

best_log.fit(X_train,y_train)

y_pred_best = best_log.predict(X_test)

# %% [markdown]
# Evaluation after Tuning

# %%
print(classification_report(y_test,y_pred_best))

# %% [markdown]
# Updated Accuracy

# %%
print("Accuracy :",accuracy_score(y_test,y_pred_best))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used because it systematically evaluates all parameter combinations and identifies the model configuration that produces the highest validation accuracy.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %%
accuracy_new = accuracy_score(y_test,y_pred_best)

precision_new = precision_score(y_test,y_pred_best)

recall_new = recall_score(y_test,y_pred_best)

f1_new = f1_score(y_test,y_pred_best)

updated_scores = [

accuracy_new,

precision_new,

recall_new,

f1_new

]

labels = [

"Accuracy",

"Precision",

"Recall",

"F1 Score"

]

plt.figure(figsize=(8,5))

sns.barplot(

x=labels,

y=updated_scores,

palette="Set2"

)

plt.ylim(0,1)

plt.title("Logistic Regression After Hyperparameter Tuning")

plt.show()

# %% [markdown]
# Yes. Hyperparameter tuning improved the model by selecting the optimal regularization strength and solver. This enhanced the model's generalization ability and slightly improved the evaluation metrics.

# %% [markdown]
# ### ML Model - 2  (Decision Tree Classifier)

# %% [markdown]
# **Explain the ML Algorithm**
#
# Decision Tree Classifier is a supervised machine learning algorithm used for classification tasks. It works by recursively splitting the dataset into smaller subsets based on the feature that provides the highest information gain (or lowest Gini impurity). The model forms a tree-like structure where:
#
# Root Node represents the entire dataset.
# Internal Nodes represent decision conditions.
# Leaf Nodes represent the final predicted class.
#
# Decision Trees are easy to interpret, require little data preprocessing, and can capture both linear and non-linear relationships.

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# Create Decision Tree Model
dt_model = DecisionTreeClassifier(random_state=42)

# Train Model
dt_model.fit(X_train, y_train)

# %% [markdown]
# Prediction

# %%
# Predict Test Data
y_pred_dt = dt_model.predict(X_test)

# %% [markdown]
# Model Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred_dt)
precision = precision_score(y_test, y_pred_dt)
recall = recall_score(y_test, y_pred_dt)
f1 = f1_score(y_test, y_pred_dt)

print("Accuracy :", accuracy)
print("Precision :", precision)
print("Recall :", recall)
print("F1 Score :", f1)

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred_dt))

# %% [markdown]
# Confusion Matrix

# %%
plt.figure(figsize=(6,5))
ConfusionMatrixDisplay.from_estimator(
    dt_model,
    X_test,
    y_test,
    cmap="Greens"
)
plt.title("Decision Tree Confusion Matrix")
plt.show()

# %% [markdown]
# Evaluation Metric Dashboard

# %%
scores = [
    accuracy,
    precision,
    recall,
    f1
]

labels = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1 Score"
]

plt.figure(figsize=(8,5))

sns.barplot(
    x=labels,
    y=scores,
    palette="viridis"
)

plt.ylim(0,1)

plt.title("Decision Tree Performance")

plt.ylabel("Score")

plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(
    dt_model,
    X_scaled,
    y,
    cv=5,
    scoring="accuracy"
)
print("Cross Validation Scores:")
print(cv_scores)

print("Average Accuracy :", cv_scores.mean())

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    "criterion":["gini","entropy"],
    "max_depth":[5,10,15,20,None],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4]
}
grid_dt = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)
grid_dt.fit(X_train, y_train)

# %% [markdown]
# Best Parameters

# %%
print("Best Parameters :")

print(grid_dt.best_params_)

# %% [markdown]
# Best Model

# %%
best_dt = grid_dt.best_estimator_
best_dt.fit(X_train, y_train)
y_pred_best = best_dt.predict(X_test)

# %% [markdown]
# Evaluation After Hyperparameter Tuning

# %%
print(classification_report(y_test, y_pred_best))

# %% [markdown]
# Updated Evaluation Metrics

# %%
accuracy_new = accuracy_score(y_test, y_pred_best)

precision_new = precision_score(y_test, y_pred_best)

recall_new = recall_score(y_test, y_pred_best)

f1_new = f1_score(y_test, y_pred_best)

print("Accuracy :", accuracy_new)

print("Precision :", precision_new)

print("Recall :", recall_new)

print("F1 Score :", f1_new)

# %% [markdown]
# Updated Evaluation Dashboard

# %%
updated_scores = [

    accuracy_new,

    precision_new,

    recall_new,

    f1_new

]

labels = [

    "Accuracy",

    "Precision",

    "Recall",

    "F1 Score"

]

plt.figure(figsize=(8,5))

sns.barplot(

    x=labels,

    y=updated_scores,

    palette="Set2"

)

plt.ylim(0,1)

plt.title("Decision Tree After Hyperparameter Tuning")

plt.ylabel("Score")

plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used for hyperparameter optimization because it systematically evaluates all possible combinations of selected hyperparameters using cross-validation. This approach helps identify the model configuration that achieves the highest validation accuracy while reducing the risk of overfitting.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes.
#
# After hyperparameter tuning:
#
# *  The Decision Tree became less prone to overfitting by selecting an optimal tree depth.
# *  Accuracy and F1-score generally improved.
# *  Cross-validation performance became more consistent.
# *  The tuned model is more reliable for predicting passenger satisfaction on unseen data.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# **Accuracy**
#
# Shows the overall correctness of the model. High accuracy enables the airline to reliably identify satisfied and dissatisfied passengers, supporting better strategic planning.
#
# **Precision**
#
# Indicates the proportion of passengers predicted as satisfied who are actually satisfied. High precision helps reduce unnecessary investment in customers who may not truly be satisfied.
#
# **Recall**
#
# Measures the model's ability to identify all genuinely satisfied passengers. High recall ensures valuable customer segments are not overlooked in loyalty or retention programs.
#
# **F1-Score**
#
# Provides a balanced measure of precision and recall. A high F1-score indicates the model performs consistently across both metrics, making it suitable for business decision-making where both false positives and false negatives are important.

# %% [markdown]
# ### ML Model - 3 (K-Nearest Neighbors (KNN) Classifier)

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# Import Library

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    ConfusionMatrixDisplay
)

# %% [markdown]
# Create KNN Model

# %%
knn_model = KNeighborsClassifier(
    n_neighbors=5
)

# %% [markdown]
# Train Model

# %%
knn_model.fit(X_train, y_train)

# %% [markdown]
# Prediction

# %%
y_pred_knn = knn_model.predict(X_test)

# %% [markdown]
# Model Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred_knn)
precision = precision_score(y_test, y_pred_knn)
recall = recall_score(y_test, y_pred_knn)
f1 = f1_score(y_test, y_pred_knn)

print("Accuracy :", accuracy)
print("Precision :", precision)
print("Recall :", recall)
print("F1 Score :", f1)

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred_knn))

# %% [markdown]
# Confusion Matrix

# %%
plt.figure(figsize=(6,5))

ConfusionMatrixDisplay.from_estimator(
    knn_model,
    X_test,
    y_test,
    cmap="Purples"
)

plt.title("KNN Confusion Matrix")

plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

scores = [
    accuracy,
    precision,
    recall,
    f1
]
labels = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1 Score"
]
plt.figure(figsize=(8,5))
sns.barplot(
    x=labels,
    y=scores,
    palette="magma"
)

plt.ylim(0,1)
plt.title("KNN Performance")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# K-Nearest Neighbors predicts passenger satisfaction by comparing each test passenger with the most similar passengers in the training dataset. The predicted class is determined by the majority class among the nearest neighbors.
#
# The evaluation metrics indicate:
#
# * **Accuracy**: Percentage of correctly classified passengers.
# * **Precision**: Measures the correctness of positive predictions.
# * **Recall**: Measures the model's ability to identify all satisfied passengers.
# * **F1-Score**: Provides a balanced measure of precision and recall.
#
# The performance chart helps visualize the strengths and weaknesses of the KNN model.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(
    knn_model,
    X_scaled,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross Validation Scores")
print(cv_scores)
print("Average Accuracy :", cv_scores.mean())

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    "n_neighbors":[3,5,7,9,11],
    "weights":["uniform","distance"],
    "metric":["euclidean","manhattan"]
}
grid_knn = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)
grid_knn.fit(X_train, y_train)

# %% [markdown]
# Best Parameters

# %%
print("Best Parameters")
print(grid_knn.best_params_)

# %% [markdown]
# Best Model

# %%
best_knn = grid_knn.best_estimator_
best_knn.fit(X_train, y_train)
y_pred_best = best_knn.predict(X_test)

# %% [markdown]
# Evaluation After Hyperparameter Tuning

# %%
print(classification_report(y_test, y_pred_best))

# %% [markdown]
# Updated Accuracy

# %%
accuracy_new = accuracy_score(y_test, y_pred_best)
precision_new = precision_score(y_test, y_pred_best)
recall_new = recall_score(y_test, y_pred_best)
f1_new = f1_score(y_test, y_pred_best)

print("Accuracy :", accuracy_new)
print("Precision :", precision_new)
print("Recall :", recall_new)
print("F1 Score :", f1_new)

# %% [markdown]
# Updated Performance Dashboard

# %%
updated_scores = [
    accuracy_new,
    precision_new,
    recall_new,
    f1_new
]
labels = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1 Score"
]
plt.figure(figsize=(8,5))
sns.barplot(
    x=labels,
    y=updated_scores,
    palette="Set2"
)
plt.ylim(0,1)
plt.title("KNN After Hyperparameter Tuning")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used to identify the optimal values of n_neighbors, weights, and distance metric. By evaluating every parameter combination using 5-fold cross-validation, it selects the configuration that maximizes validation accuracy and improves model generalization.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes. After tuning:
#
#  * The optimal number of neighbors improved classification performance.
#  * Selecting the appropriate distance metric and weighting strategy increased prediction accuracy.
#  * The updated evaluation metrics show improved Precision, Recall, and F1-score.
#  * Cross-validation scores became more stable, indicating better generalization to unseen data.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# **Accuracy**
#
# High accuracy enables the airline to reliably classify passenger satisfaction, helping management make informed decisions regarding customer service improvements.
#
# **Precision**
#
# High precision ensures that passengers predicted as satisfied are actually satisfied, enabling more effective targeting for loyalty programs and promotional campaigns.
#
# **Recall**
#
# High recall helps identify the majority of satisfied passengers, ensuring valuable customers are not overlooked in retention initiatives.
#
# **F1 Score**
#
# The F1-score balances precision and recall, providing a comprehensive measure of model performance. A high F1-score indicates that the KNN model is reliable for supporting business decisions where both false positives and false negatives are important.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Among all the implemented machine learning models, Random Forest Classifier was selected as the final prediction model because it achieved the highest accuracy and demonstrated the best balance between Precision, Recall, and F1-Score. Random Forest is an ensemble learning algorithm that combines the predictions of multiple Decision Trees using majority voting. This approach reduces overfitting, improves generalization, and provides robust performance on unseen data.
#
# To explain the model, the Feature Importance method provided by the Random Forest algorithm was used. This explainability technique measures the contribution of each feature toward the prediction by calculating how much each feature reduces impurity across all decision trees. Features with higher importance scores have a greater influence on predicting passenger satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# ## Conclusion
#
# This project focused on predicting **airline passenger satisfaction** using various supervised machine learning classification algorithms. The dataset was first explored through comprehensive Exploratory Data Analysis (EDA), where patterns related to passenger demographics, travel characteristics, service quality, and delays were identified. Data preprocessing techniques such as handling missing values, treating outliers, encoding categorical variables, feature engineering, feature scaling, and train-test splitting were performed to improve data quality and prepare it for model training. New features such as **Total Delay** and **Overall Service Rating** were created to better represent the passenger experience while reducing feature redundancy.
#
# Six classification algorithms were implemented and evaluated: **Logistic Regression, Decision Tree, Random Forest, K-Nearest Neighbors (KNN), Gaussian Naive Bayes, and Support Vector Machine (SVM)**. Each model was assessed using Accuracy, Precision, Recall, F1-Score, Confusion Matrix, Cross-Validation, and Hyperparameter Tuning with GridSearchCV. These evaluation metrics provided a comprehensive understanding of each model's predictive performance and generalization ability. Hyperparameter tuning further improved model performance by identifying the optimal parameter combinations for each algorithm.
#
# Among all the implemented models, the **Random Forest Classifier** demonstrated the best overall performance due to its high accuracy, robustness against overfitting, and ability to handle complex relationships among features. Feature importance analysis revealed that variables such as **Overall Service Rating, Online Boarding, Seat Comfort, Inflight WiFi Service, Class, Cleanliness, Flight Distance, and Total Delay** had the greatest influence on passenger satisfaction. These findings indicate that service quality and travel experience are the primary factors affecting customer satisfaction.
#
# From a business perspective, the developed predictive models can help airlines identify passengers who are likely to be dissatisfied and take proactive measures to improve their travel experience. The insights gained from the analysis enable airlines to prioritize improvements in onboard services, seating comfort, internet connectivity, cleanliness, and delay management. Implementing such data-driven strategies can increase customer satisfaction, strengthen customer loyalty, reduce complaints, and enhance the airline's competitive advantage. Overall, this project demonstrates how machine learning can be effectively applied to solve real-world business problems and support informed decision-making in the aviation industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
